# %%
import torch
import torch.optim as optim
from torchvision import datasets, transforms
import torch.nn as nn
import torch.nn.functional as F
from resnet import CustomResNet
from utils import *
from tqdm import tqdm
# %pip install torchsummary
from torchsummary import summary


import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# Requirement already satisfied: torchsummary in c:\users\shash\anaconda3\lib\site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from Dataset import CIFAR10
from torchvision import transforms
batch_size = 512
cifar10 = CIFAR10(batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cifar10.show_examples()

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

model = CustomResNet(dropout= 0.05).to(device)
summary(model, input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#            Dropout-4           [-1, 64, 32, 32]               0
#          ConvLayer-5           [-1, 64, 32, 32]               0
#        CustomLayer-6           [-1, 64, 32, 32]               0
#             Conv2d-7          [-1, 128, 32, 32]          73,728
#          MaxPool2d-8          [-1, 128, 16, 16]               0
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#           Dropout-11          [-1, 128, 16, 16]               0
#         ConvLayer-12          [-1, 128, 16, 16]               0
#            Conv2d-13          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#              ReLU-15          [-1, 128, 16, 16]               0
#           Dropout-16          [-1, 128, 16, 16]               0
#         ConvLayer-17          [-1, 128, 16, 16]               0
#            Conv2d-18          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-19          [-1, 128, 16, 16]             256
#              ReLU-20          [-1, 128, 16, 16]               0
#           Dropout-21          [-1, 128, 16, 16]               0
#         ConvLayer-22          [-1, 128, 16, 16]               0
#       CustomLayer-23          [-1, 128, 16, 16]               0
#            Conv2d-24          [-1, 256, 16, 16]         294,912
#         MaxPool2d-25            [-1, 256, 8, 8]               0
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#              ReLU-27            [-1, 256, 8, 8]               0
#           Dropout-28            [-1, 256, 8, 8]               0
#         ConvLayer-29            [-1, 256, 8, 8]               0
#       CustomLayer-30            [-1, 256, 8, 8]               0
#            Conv2d-31            [-1, 512, 8, 8]       1,179,648
#         MaxPool2d-32            [-1, 512, 4, 4]               0
#       BatchNorm2d-33            [-1, 512, 4, 4]           1,024
#              ReLU-34            [-1, 512, 4, 4]               0
#           Dropout-35            [-1, 512, 4, 4]               0
#         ConvLayer-36            [-1, 512, 4, 4]               0
#            Conv2d-37            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#              ReLU-39            [-1, 512, 4, 4]               0
#           Dropout-40            [-1, 512, 4, 4]               0
#         ConvLayer-41            [-1, 512, 4, 4]               0
#            Conv2d-42            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-43            [-1, 512, 4, 4]           1,024
#              ReLU-44            [-1, 512, 4, 4]               0
#           Dropout-45            [-1, 512, 4, 4]               0
#         ConvLayer-46            [-1, 512, 4, 4]               0
#       CustomLayer-47            [-1, 512, 4, 4]               0
#         MaxPool2d-48            [-1, 512, 1, 1]               0
#           Flatten-49                  [-1, 512]               0
#            Linear-50                   [-1, 10]           5,130
# ================================================================
# Total params: 6,573,130
# Trainable params: 6,573,130
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 10.51
# Params size (MB): 25.07
# Estimated Total Size (MB): 35.59
# ----------------------------------------------------------------

# %%
from experiment import Experiment
exp = Experiment(model, cifar10)
# Out:
# Device Selected: cuda
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1
# Test:  Average loss: 0.5186, Accuracy: 82.27
# Epoch: 17
# Train: Average Loss: 0.4609, Accuracy: 83.99 LR: 3.9511354077572e-05: 100%|██████████| 98/98 [01:29<00:00,  1.10it/s]
# Test:  Average loss: 0.5026, Accuracy: 82.81
# Epoch: 18
# Train: Average Loss: 0.4382, Accuracy: 84.98 LR: 3.3868406733950294e-05: 100%|██████████| 98/98 [01:28<00:00,  1.11it/s]
# Test:  Average loss: 0.4747, Accuracy: 83.75
# Epoch: 19
# Train: Average Loss: 0.4265, Accuracy: 85.30 LR: 2.8225459390328602e-05: 100%|██████████| 98/98 [01:26<00:00,  1.13it/s]
# Test:  Average loss: 0.4466, Accuracy: 84.64
# Epoch: 20
# Train: Average Loss: 0.4084, Accuracy: 86.23 LR: 2.2582512046706896e-05: 100%|██████████| 98/98 [01:34<00:00,  1.03it/s]
# Test:  Average loss: 0.4313, Accuracy: 85.36
# Epoch: 21
# Train: Average Loss: 0.3903, Accuracy: 86.53 LR: 1.6939564703085205e-05: 100%|██████████| 98/98 [01:28<00:00,  1.11it/s]
# Test:  Average loss: 0.4271, Accuracy: 85.38
# Epoch: 22
# Train: Average Loss: 0.3764, Accuracy: 87.15 LR: 1.12966173594635e-05: 100%|██████████| 98/98 [01:29<00:00,  1.09it/s]
# Test:  Average loss: 0.4204, Accuracy: 85.87
# Epoch: 23
#   0%|          | 0/98 [00:51<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 exp.execute()
#
# File c:\Users\shash\OneDrive\Documents\GitHub\ERA-S10-Custom-ResNet\experiment.py:45, in Experiment.execute(self, target)
#      43 for epoch in range(1, self.epochs + 1):
#      44     print(f'Epoch: {epoch}')
# ---> 45     self.train()
#      46     test_loss, test_acc = self.test()
#      47     if target is not None and test_acc >= target:
#
# File c:\Users\shash\OneDrive\Documents\GitHub\ERA-S10-Custom-ResNet\backprop.py:41, in Train.__call__(self)
#      38 correct = 0
#      39 processed = 0
# ---> 41 for batch_idx, (data, target) in enumerate(pbar):
#      42     data, target = data.to(self.device), target.to(self.device)
#      43     self.optimizer.zero_grad()
#
# File c:\Users\shash\anaconda3\lib\site-packages\tqdm\std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\shash\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:441, in DataLoader.__iter__(self)
#     439     return self._iterator
#     440 else:
# --> 441     return self._get_iterator()
#
# File c:\Users\shash\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:388, in DataLoader._get_iterator(self)
#     386 else:
#     387     self.check_worker_number_rationality()
# --> 388     return _MultiProcessingDataLoaderIter(self)
#
# File c:\Users\shash\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:1042, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1035 w.daemon = True
#    1036 # NB: Process.start() actually take some time as it needs to
#    1037 #     start a process and pass the arguments over via a pipe.
#    1038 #     Therefore, we only add a worker to self._workers list after
#    1039 #     it started, so that we do not call .join() if program dies
#    1040 #     before it starts, and __del__ tries to join but will get:
#    1041 #     AssertionError: can only join a started process.
# -> 1042 w.start()
#    1043 self._index_queues.append(index_queue)
#    1044 self._workers.append(w)
#
# File c:\Users\shash\anaconda3\lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Users\shash\anaconda3\lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File c:\Users\shash\anaconda3\lib\multiprocessing\context.py:327, in SpawnProcess._Popen(process_obj)
#     324 @staticmethod
#     325 def _Popen(process_obj):
#     326     from .popen_spawn_win32 import Popen
# --> 327     return Popen(process_obj)
#
# File c:\Users\shash\anaconda3\lib\multiprocessing\popen_spawn_win32.py:93, in Popen.__init__(self, process_obj)
#      91 try:
#      92     reduction.dump(prep_data, to_child)
# ---> 93     reduction.dump(process_obj, to_child)
#      94 finally:
#      95     set_spawning_popen(None)
#
# File c:\Users\shash\anaconda3\lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:
